# %% [markdown]
# # Face tracking pipeline
#
# The following example illustrates how to use the `facenet_pytorch` python package to perform face detection and tracking on an image dataset using MTCNN.

# %%
from facenet_pytorch import MTCNN
import torch
import mmcv, cv2
import numpy as np
from PIL import Image, ImageDraw
from IPython import display

# %% [markdown]
# #### Determine if an nvidia GPU is available

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print('Running on device: {}'.format(device))
# Out:
# Running on device: cuda:0

# %% [markdown]
# #### Define MTCNN module
#
# Note that, since MTCNN is a collection of neural nets and other code, the device must be passed in the following way to enable copying of objects when needed internally.
#
# See `help(MTCNN)` for more details.

# %%
mtcnn = MTCNN(keep_all=True, device=device)

# %% [markdown]
# #### Get a sample video
#
# We begin by loading a video with some faces in it. The `mmcv` PyPI package by mmlabs is used to read the video frames (it can be installed with `pip install mmcv`). Frames are then converted to PIL images.

# %%
video = mmcv.VideoReader("video.mp4")
frames = [Image.fromarray(frame[:, :, ::-1]) for frame in video]

display.Video("video.mp4", width=640)
# Out:
# <video src="video.mp4" controls  width="640" >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# #### Run video through MTCNN
#
# We iterate through each frame, detect faces, and draw their bounding boxes on the video frames.

# %%
frames_tracked = []
for i, frame in enumerate(frames):
    print('\rTracking frame: {}'.format(i + 1), end='')
    
    # Detect faces
    boxes, _, _ = mtcnn.detect([frame])
    
    # Draw faces
    frame_draw = frame.copy()
    draw = ImageDraw.Draw(frame_draw)
    for box in boxes[0]:
        draw.rectangle(box.tolist(), outline=(255, 0, 0), width=6)
    
    # Add to frame list
    frames_tracked.append(frame_draw.resize((640, 360), Image.BILINEAR))
print('\nDone')
# Out:
# Tracking frame: 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 6
#       3 print('\rTracking frame: {}'.format(i + 1), end='')
#       5 # Detect faces
# ----> 6 boxes, _, _ = mtcnn.detect([frame])
#       8 # Draw faces
#       9 frame_draw = frame.copy()
#
# File ~/src/facenet-pytorch/facenet_pytorch/models/mtcnn.py:366, in MTCNN.detect(self, imgs)
#     334 def detect(self, imgs: list[Image | np.ndarray | torch.Tensor]) -> tuple[np.ndarray, np.ndarray, np.ndarray]:
#     335     """Detect all faces in PIL image and return bounding boxes and optional facial landmarks.
#     336
#     337     This method is used by the forward method and is also useful for face detection tasks
#    (...)
#     364     >>> img_draw.save("annotated_faces.png")
#     365     """
# --> 366     batch_boxes, batch_probs, batch_points = self.detect_impl(imgs)
#     367     # Select faces
#     368     if not self.keep_all:
#
# File ~/src/facenet-pytorch/facenet_pytorch/models/mtcnn.py:412, in MTCNN.detect_impl(self, imgs)
#     376 """Detect all faces in PIL image and return bounding boxes and optional facial landmarks.
#     377
#     378 This method is used by the forward method and is also useful for face detection tasks
#    (...)
#     409 >>> img_draw.save("annotated_faces.png")
#     410 """
#     411 with torch.no_grad():
# --> 412     batch_boxes, batch_points = detect_face(
#     413         imgs, self.min_face_size, self.pnet, self.rnet, self.onet, self.thresholds, self.factor, self.device
#     414     )
#     416 boxes, probs, points = [], [], []
#     417 for box, point in zip(batch_boxes, batch_points):
#
# File ~/src/facenet-pytorch/facenet_pytorch/models/utils/detect_face.py:216, in detect_face(imgs, min_size, pnet, rnet, onet, threshold, factor, device)
#     213     bboxes = convert_to_square(bboxes)
#     215 # Third stage
# --> 216 if len(bboxes) > 0:
#     217     im_data = get_image_boxes(bboxes, imgs, image_idxs, 48)
#     219     # This is equivalent to out = onet(im_data) to avoid GPU out of memory.
#
# File ~/src/facenet-pytorch/facenet_pytorch/models/utils/detect_face.py:216, in detect_face(imgs, min_size, pnet, rnet, onet, threshold, factor, device)
#     213     bboxes = convert_to_square(bboxes)
#     215 # Third stage
# --> 216 if len(bboxes) > 0:
#     217     im_data = get_image_boxes(bboxes, imgs, image_idxs, 48)
#     219     # This is equivalent to out = onet(im_data) to avoid GPU out of memory.
#
# File /snap/pycharm-professional/395/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_frame.py:755, in PyDBFrame.trace_dispatch(self, frame, event, arg)
#     753 # if thread has a suspend flag, we suspend with a busy wait
#     754 if info.pydev_state == STATE_SUSPEND:
# --> 755     self.do_wait_suspend(thread, frame, event, arg)
#     756     # No need to reset frame.f_trace to keep the same trace function.
#     757     return self.trace_dispatch
#
# File /snap/pycharm-professional/395/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_frame.py:412, in PyDBFrame.do_wait_suspend(self, *args, **kwargs)
#     411 def do_wait_suspend(self, *args, **kwargs):
# --> 412     self._args[0].do_wait_suspend(*args, **kwargs)
#
# File /snap/pycharm-professional/395/plugins/python/helpers/pydev/pydevd.py:1196, in PyDB.do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1193         from_this_thread.append(frame_id)
#    1195 with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1196     self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#
# File /snap/pycharm-professional/395/plugins/python/helpers/pydev/pydevd.py:1211, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1208             self._call_mpl_hook()
#    1210         self.process_internal_commands()
# -> 1211         time.sleep(0.01)
#    1213 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    1215 # process any stepping instructions
#
# KeyboardInterrupt:

# %% [markdown]
# #### Display detections

# %%
d = display.display(frames_tracked[0], display_id=True)
i = 1
try:
    while True:
        d.update(frames_tracked[i % len(frames_tracked)])
        i += 1
except KeyboardInterrupt:
    pass
# Out:
# <PIL.Image.Image image mode=RGB size=640x360>

# %% [markdown]
# #### Save tracked video

# %%
dim = frames_tracked[0].size
fourcc = cv2.VideoWriter_fourcc(*'FMP4')    
video_tracked = cv2.VideoWriter('video_tracked.mp4', fourcc, 25.0, dim)
for frame in frames_tracked:
    video_tracked.write(np.asarray(frame)[:, :, ::-1])
video_tracked.release()
# Out:
# OpenCV: FFMPEG: tag 0x34504d46/'FMP4' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
